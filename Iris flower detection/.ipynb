# %% [markdown]
# #  Project with Iris Flower

# %% [markdown]
# Lets, Predict which kind of IRIS Flower by using  petal and sepal Length

# %% [markdown]
# <center><img src="iris.png"><img src="iris_data.png"> </center>

# %%
# import load_iris function from datasets module
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
iris = load_iris() #this dataset comes with anaconda
iris.keys()
# Out:
# dict_keys(['data', 'target', 'target_names', 'DESCR', 'feature_names', 'filename'])

# %%
iris.data
#iris.target
#iris.target_names
#iris.DESCR
iris.feature_names
#iris.filename
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
i_data=pd.DataFrame(iris.data)
type(i_data)
# Out:
# pandas.core.frame.DataFrame

# %%
i_data.head(5)
# Out:
#      0    1    2    3
# 0  5.1  3.5  1.4  0.2
# 1  4.9  3.0  1.4  0.2
# 2  4.7  3.2  1.3  0.2
# 3  4.6  3.1  1.5  0.2
# 4  5.0  3.6  1.4  0.2

# %%
X, y = iris["data"], iris["target"]
X.shape
# Out:
# (150, 4)

# %%
y.shape
# Out:
# (150,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=10)

# %%
#DecisionTreeClassifier is a class capable of performing multi-class classification on a dataset
#To learn more go to the link: https://scikit-learn.org/stable/modules/tree.html  
from sklearn import tree

clf_dt = tree.DecisionTreeClassifier()
clf_dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
#Accuracy of DecisionTreeClassifier Model
clf_dt.score(X_test, y_test)
# Out:
# 0.9666666666666667
